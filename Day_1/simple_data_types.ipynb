# %%
number = 5
print(number)
# Out:
# 5

# %%
name = "seud"
print(name)
# Out:
# seud

# %%
gpa = 3.6
print(gpa)
# Out:
# 3.6

# %%
fname = "seud"
lname = "abdulsemed"
full_name = fname + " " + lname
print(full_name)
# Out:
# seud abdulsemed

# %%
print(full_name[:6])
# Out:
# seud a

# %%
print(full_name[0:7])
# Out:
# seud ab

# %%
print(full_name[3:])
# Out:
# d abdulsemed

# %%
print(full_name[:])
# Out:
# seud abdulsemed

# %%
print(full_name[::-1])
# Out:
# demesludba dues

# %%
ugly_sentence = "Seud, 25, Computer Science"
cleaned = ugly_sentence.strip()
print(cleaned)
# Out:
# Seud, 25, Computer Science

# %%
to_list = cleaned.split(",")
print(to_list)
# Out:
# ['Seud', ' 25', ' Computer Science']

# %%
epoch = 5
loss = 0.02314
print(f"Epoch: {epoch:03d} | Loss: {loss:4f}")
# Out:
# Epoch: 005 | Loss: 0.023140
